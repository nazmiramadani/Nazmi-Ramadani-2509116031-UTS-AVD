# %% [markdown]
# # **Analisis Perkembangan Energi Terbarukan dan Fosil Dunia**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # **Bussines Understanding**

# %% [markdown]
# ## **Bussines Objective**
#
# Dataset ini bertujuan untuk memahami tren penggunaan energi terbarukan dan energi fosil secara global agar pengambilan keputusan dalam sektor energi dapat dilakukan secara strategis. Analisis ini bertujuan untuk mengidentifikasi pergeseran penggunaan energi fosil ke energi terbarukan, menilai tingkat ketergantungan suatu negara terhadap energi fosil, serta membuat pertimbangan dalam perencanaan kebijakan energi dan transisi energi berkelanjutan

# %% [markdown]
# ## **Assess Situation**
#
# Berdasarkan dataset tersebut kebutuhan energi dunia terus meningkat, sementara isu perubahan iklim semakin serius. banyak negara mulai menggunakan energi terbarukan, akan tetapi energi fosil juga masih sangat banyak dipakai.

# %% [markdown]
# ## **Analytic Goals**
#
# * Menganalisis tren penggunaan energi dari tahun ke tahun
# * Membandingkan penggunaan energi terbanyak tiap negara
# * Melihat pergeseran energi fosil ke energi terbarukan
# * Mengukur kontribusi energi terbarukan terhadap total konsumsi energi

# %% [markdown]
# ## **Project Plan**
#
# * Memahami isi dataset
# * Memvisualisasikan isi Dataset
# * Memanfaatkan isi dataset
# * Membuat kesimpulan dari isi dataset

# %% [markdown]
# # **Data Understanding**

# %% [markdown]
# ## **Memuat Dataset**

# %%
file = "/content/drive/MyDrive/Check_point_AVD/global_renewable_and_fossil_fuel_energy_2000_2022.csv"
df = pd.read_csv(file)

df
# Out:
#        country country_code                      region  year  \
# 0        Aruba          ABW  Latin America & Caribbean   2000
# 1        Aruba          ABW  Latin America & Caribbean   2001
# 2        Aruba          ABW  Latin America & Caribbean   2002
# 3        Aruba          ABW  Latin America & Caribbean   2003
# 4        Aruba          ABW  Latin America & Caribbean   2004
# ...        ...          ...                         ...   ...
# 4852  Zimbabwe          ZWE         Sub-Saharan Africa   2018
# 4853  Zimbabwe          ZWE         Sub-Saharan Africa   2019
# 4854  Zimbabwe          ZWE         Sub-Saharan Africa   2020
# 4855  Zimbabwe          ZWE         Sub-Saharan Africa   2021
# 4856  Zimbabwe          ZWE         Sub-Saharan Africa   2022
#
#       renewable_energy_percent  fossil_fuel_energy_percent  \
# 0                          0.2                         NaN
# 1                          0.2                         NaN
# ...

# %% [markdown]
# ## **Deskripsi Data**

# %% [markdown]
# ### **Informasi Dasar**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4857 entries, 0 to 4856
# Data columns (total 10 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   country                              4857 non-null   object
#  1   country_code                         4857 non-null   object
#  2   region                               4857 non-null   object
#  3   year                                 4857 non-null   int64
#  4   renewable_energy_percent             4702 non-null   float64
#  5   fossil_fuel_energy_percent           3380 non-null   float64
#  6   electricity_from_renewables_percent  4396 non-null   float64
#  7   electricity_from_fossil_percent      4648 non-null   float64
#  8   total_electricity_share              4359 non-null   float64
#  9   clean_energy_dominant                4857 non-null   bool
# dtypes: bool(1), float64(5), int64(1), object(3)
# memory usage: 346.4+ KB

# %% [markdown]
# Berdasarkan data di atas, dapat diketahui bahwa dataset ini memiliki 4857 Baris dan 10 Kolom

# %% [markdown]
# ### **Informasi Lanjutan**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4857 entries, 0 to 4856
# Data columns (total 10 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   country                              4857 non-null   object
#  1   country_code                         4857 non-null   object
#  2   region                               4857 non-null   object
#  3   year                                 4857 non-null   int64
#  4   renewable_energy_percent             4702 non-null   float64
#  5   fossil_fuel_energy_percent           3380 non-null   float64
#  6   electricity_from_renewables_percent  4396 non-null   float64
#  7   electricity_from_fossil_percent      4648 non-null   float64
#  8   total_electricity_share              4359 non-null   float64
#  9   clean_energy_dominant                4857 non-null   bool
# dtypes: bool(1), float64(5), int64(1), object(3)
# memory usage: 346.4+ KB

# %% [markdown]
# 1. country:
#         Jumlah baris: 4857,
#         Tipe data: Object,
#         Deskripsi: Nama Negara.
#
# 2. country_code:
#         Jumlah baris: 4857,
#         Tipe data: Object,
#         Deskripsi: Kode Negara.
#
# 3. region:
#         Jumlah baris: 4857,
#         Tipe data: Object,
#         Deskripsi: Wilayah Geografis .
#
# 4. year:
#         Jumlah baris: 4857,
#         Tipe data: int64,
#         Deskripsi: Tahun pengamatan data energi.
#
# 5. renewable_energy_percent:
#         Jumlah baris: 4702,
#         Tipe data: float64,
#         Deskripsi: Persentase total konsumsi energi yang berasal dari sumber energi terbarukan.
#
# 6. fossil_fuel_energy_percent:
#         Jumlah baris: 3380,
#         Tipe data: float64,
#         Deskripsi: Persentase total konsumsi energi yang berasal dari bahan bakar fosil.
#
# 7. electricity_from_renewables_percent:
#         Jumlah baris: 4396,
#         Tipe data: float64,
#         Deskripsi: Persentase produksi listrik dari sumber energi terbarukan.
#
# 8. electricity_from_fossil_percent:
#         Jumlah baris: 4648,
#         Tipe data: float64,
#         Deskripsi: Persentase produksi listrik dari bahan bakar fosil.
#
# 9. total_electricity_share:
#         Jumlah baris: 4359,
#         Tipe data: float64,
#         Deskripsi: Proporsi listrik terhadap total konsumsi energi.
#
# 10. clean_energy_dominant:
#         Jumlah baris: 4857,
#         Tipe data: Bool,
#         Deskripsi: Menunjukkan apakah energi bersih lebih dominan dibandingkan energi fosil.

# %% [markdown]
# ### **Informasi Statistik Deskriptif**

# %%
df.describe(include='all')
# Out:
#        country country_code                 region         year  \
# count     4857         4857                   4857  4857.000000
# unique     213          213                      7          NaN
# top      Aruba          ABW  Europe & Central Asia          NaN
# freq        23           23                   1249          NaN
# mean       NaN          NaN                    NaN  2011.030471
# std        NaN          NaN                    NaN     6.624015
# min        NaN          NaN                    NaN  2000.000000
# 25%        NaN          NaN                    NaN  2005.000000
# 50%        NaN          NaN                    NaN  2011.000000
# 75%        NaN          NaN                    NaN  2017.000000
# max        NaN          NaN                    NaN  2022.000000
#
#         renewable_energy_percent  fossil_fuel_energy_percent  \
# count                4702.000000                 3380.000000
# unique                       NaN                         NaN
# ...

# %% [markdown]
# 1. Count (Kelengkapan Data)
# Berdasarkan data, total baris adalah 4857. Maka dapat disimpulkan:
# * renewable_energy_percent kehilangan 155 data (4.857 - 4.702)
# * fossil_fuel_energy_percent kehilangan 1.477 data (4.857 - 3.380)
# * electricity_from_renewables_percent kehilangan 461 data (4.857 - 4.396)
# * electricity_from_fossil_percent kehilangan 209 data (4.857 - 4.648)
# * total_electricity_share kehilangan 498 data (4.857 - 4.359)
#
# Kesimpulan: Kolom renewable_energy_percent, fossil_fuel_energy_percent, electricity_from_renewables_percent, electricity_from_fossil_percent, dan total_electricity_share mengandung missing values, sedangkan untuk kolom yang lain sudah lengkap (4.857)
#
#
#
# ---
#
#
#
# 2. Mean vs Median (Distribusi Data)
# * renewable_energy_percent
#   * Mean = 29,85
#   * Median = 19,10 - Nilai mean lebih besar dari median
#
# Distribusi condong ke kanan (right-skewed). Artinya, ada beberapa negara dengan persentase energi terbarukan yang sangat tinggi.
#
# * Fossil_Fuel_Energy_Percent
#   * Mean = 41,38
#   * Median = 39,04 - Nilai mean dan median relatif berdekatan
#
# Distribusi data cukup seimbang, meskipun masih terdapat beberapa nilai ekstrem.
#
# * Electricity_from_Renewables_Percent
#   * Mean = 29,72
#   * Median = 16,83 - Perbedaan mean dan median cukup besar
#
# Hanya sebagian kecil negara yang memiliki produksi listrik terbarukan yang tinggi.
#
# * Electricity_from_Fossil_Percent
#   * Mean = 64,04
#   * Median = 73,16 - Median lebih besar dari mean
#
#  Sebagian besar negara masih sangat bergantung pada listrik berbasis bahan bakar fosil.
#
# * Total_Electricity_Share
#   * Mean = 96,03
#   * Median = 100,00
#
# Median mencapai 100% menunjukkan bahwa listrik menjadi sumber energi utama di sebagian besar negara.
#
# Kesimpulan:
# Sebagian besar variabel energi memiliki distribusi yang tidak simetris dan dipengaruhi oleh nilai ekstrem.
#
#
# ---
#
#
#
# 3. Min dan Max (Validasi Logika)
# * Renewable_Energy_Percent
#   * Min = 0,00
#   * Max = 98,30
#
# * FossiL_Fuel_Energy_Percent
#   * Min = -61,38
#   * Max = 99,99
#
# * Electricity_from_Renewables_Percent
#   * Min = 0,00
#   * Max = 100,00
#
# * Electricity_from_Fossil_Percent
#   * Min = 0,00
#   * Max = 100,00
#
# * Total_Electricity_Share
#   * Min = 19,42
#   * Max = 172,45
#
# Kesimpulan:
#
# * Nilai negatif pada fossil_fuel_energy_percent menunjukkan adanya data yang tidak wajar.
#
# * Nilai total_electricity_share yang melebihi 100% menunjukkan adanya data yang tidak wajar.
#
# * Secara umum, rentang nilai menunjukkan perbedaan kondisi energi antar negara.
#
#
# ---
#
#
# 4. Standar Deviasi (Variabilitas Data)
#
# * Renewable_Energy_Percent
#   * Mean = 29,85
#   * Std = 29,53
#
# * Fossil Fuel_Energy_Percent
#   * Mean = 41,38
#   * Std = 38,94
#
# * Electricity_from_Renewables_Percent
#   * Mean = 29,72
#   * Std = 31,62
#
# * Electricity_from_Fossil_Percent
#   * Mean = 64,04
#   * Std = 34,20
#
# Kesimpulan:
# * Nilai standar deviasi yang cukup besar menunjukkan bahwa penggunaan energi terbarukan dan fosil sangat bervariasi antar negara.

# %% [markdown]
# ## **VERIFIKASI KUALITAS DATA**

# %% [markdown]
# ### **Data Type Check**

# %% [markdown]
# Kita akan mengecek tipe data dari setiap kolom apakah sudah sesuai atau tidak. Agar insight serta visualisasi yang akan kita buat menjadi akurat.
#
# Dapat dilihat dibawah, semua kolom sudah sesuai tipe datanya dan tidak terdapat kesalahan.

# %%
df.dtypes
# Out:
# country                                 object
# country_code                            object
# region                                  object
# year                                     int64
# renewable_energy_percent               float64
# fossil_fuel_energy_percent             float64
# electricity_from_renewables_percent    float64
# electricity_from_fossil_percent        float64
# total_electricity_share                float64
# clean_energy_dominant                     bool
# dtype: object

# %% [markdown]
# ### **Inconsistent Values**

# %% [markdown]
# Pada tahap ini, kita perlu mengecek kekonsistenan data, contoh nya dalam penulisan. Hal ini dilakukan agar data tidak terduplikat dengan baris yang sebenarnya sama akan tetapi bisa terduplikat karena tidak konsisten.
#
# Terdapat nilai yang tidak konsisten seperti persentase negatif dan nilai di atas 100%, yang secara logika tidak wajar untuk data persentase. Hal ini kemungkinan disebabkan oleh kesalahan pencatatan atau metode perhitungan tertentu.

# %% [markdown]
# ### **Missing Values**

# %% [markdown]
# Pada tahap ini, kita akan melihat seberapa banyak data yang hilang pada seluruh kolom. Dan terlihat bahwa kolom:
# * renewable_energy_percent
#
# Memiliki missing values sekitar 3% yang dimana hal ini perlu ditangani dengan cara mau ditangani atau dihapus.
#
# * fossil_fuel_percent
#
# Memiliki missing values sekitar 30% yang dimana hal ini perlu ditangani dengan cara mau ditangani atau dihapus.
#
# * electricity_from_renewables_percent
#
# Memiliki missing values sekitar 9% yang dimana hal ini perlu ditangani dengan cara mau ditangani atau dihapus.
#
# * electricity_from_fossil_percent
#
# Memiliki missing values sekitar 4% yang dimana hal ini perlu ditangani dengan cara mau ditangani atau dihapus.
#
# * total_electricity_share
#
# Memiliki missing values sekitar 10% yang dimana hal ini perlu ditangani dengan cara mau ditangani atau dihapus.

# %%
pd.DataFrame(df.isna().sum() / len(df) * 100, columns=['Null Ratio in %'])
# Out:
#                                      Null Ratio in %
# country                                     0.000000
# country_code                                0.000000
# region                                      0.000000
# year                                        0.000000
# renewable_energy_percent                    3.191270
# fossil_fuel_energy_percent                 30.409718
# electricity_from_renewables_percent         9.491456
# electricity_from_fossil_percent             4.303068
# total_electricity_share                    10.253243
# clean_energy_dominant                       0.000000

# %% [markdown]
# ### **Duplicated Values**

# %% [markdown]
# Pada tahap ini, kita akan mengecek duplikasi pada dataset. Hal ini dilakukan agar dataset memiliki insight dan hasil yang bersih.

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [country, country_code, region, year, renewable_energy_percent, fossil_fuel_energy_percent, electricity_from_renewables_percent, electricity_from_fossil_percent, total_electricity_share, clean_energy_dominant]
# Index: []

# %% [markdown]
# Terlihat pada dataset ini tidak ada duplikasi. Maka hal ini tidak perlu ditangani.

# %% [markdown]
# ### **Outliers Values**

# %% [markdown]
# Pada tahap ini, kita akan melihat nilai ekstrem (outliers) pada kolom yang bertipe data numerik. Hal ini dilakukan agar mendapatkan insight yang akurat sehingga dapat memperkuat analisis dan model yang akan kita bangun nantinya.
#
# Akan tetapi memang tidak semua kolom perlu kita tangani, kita harus tetap melihat dan memahami tujuan dari setiap kolom yang ada di dataset.
#
# Dan terlihat kolom
#
# * total_electricity_share
#
# Dengan persentase 25%

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

display(results_df)
# Out:
# Kolom                                Persentase Outliers
# year                                            0.000000
# renewable_energy_percent                        0.000000
# fossil_fuel_energy_percent                      0.000000
# electricity_from_renewables_percent             0.000000
# electricity_from_fossil_percent                 0.000000
# total_electricity_share                        25.427218

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(y=df['total_electricity_share'])
plt.title('Boxplot of total_electricity_share')
plt.ylabel('total_electricity_share')
plt.show()

# %% [markdown]
# # **Eksplorasi Data Analysis(EDA)**

# %% [markdown]
# ## **Comparison/Perbandingan**

# %% [markdown]
# Aktivitas:
# Membandingkan persentase energi terbarukan dan energi fosil antar wilayah
#
# Tujuan:
# Mengetahui perbedaan penggunaan energi antar wilayah.
#
# Visualisasi:
# Bar Chart

# %%
Renewable = df.groupby('region')['renewable_energy_percent'].sum().sort_values(ascending=False)

plt.figure(figsize=(14,7))
sns.barplot(x=Renewable.index, y=Renewable.values, palette='viridis', hue=Renewable.index, legend=False)
plt.title('Total Penggunaan Renewable Energy')
plt.xlabel('region')
plt.ylabel('renewable_energy_percent')
plt.xticks(rotation=70)
plt.show()

# %% [markdown]
# Dapat dilihat pada tabel untuk penggunaan renewable energy yang paling banyak ada pada region Sub-Saharan Africa dan yang paling sedikit adalah North America.

# %%
Fossil = df.groupby('region')['fossil_fuel_energy_percent'].sum().sort_values(ascending=False)

plt.figure(figsize=(14,7))
sns.barplot(x=Fossil.index, y=Fossil.values, palette='viridis', hue=Fossil.index, legend=False)
plt.title('Total Penggunaan Fossil Energy')
plt.xlabel('region')
plt.ylabel('fossil_fuel_energy_percent')
plt.xticks(rotation=70)
plt.show()

# %% [markdown]
# Dapat dilihat pada tabel untuk penggunaan Fossil Energy paling banyak pada region Europe & Central Asia dan yang paling sedikit adalah North America.

# %% [markdown]
# ## **Composition/Komposisi**

# %% [markdown]
# Aktivitas:
# Menganalisis komposisi bauran energi antara energi terbarukan dan energi fosil dalam total energi dan listrik.
#
# Tujuan:
# Memahami kontribusi masing-masing sumber energi dan melihat dominasi energi bersih atau fosil.
#
# Visualisasi:
# Pie Chart

# %%
total_energy = df[
    ['renewable_energy_percent', 'fossil_fuel_energy_percent']
].mean()

plt.figure(figsize=(7, 7))
plt.pie(
    total_energy,
    labels=['Renewable Energy', 'Fossil Fuel Energy'],
    autopct='%1.1f%%',
    startangle=140
)
plt.title('Komposisi Bauran Energi (Total Energi)')
plt.axis('equal')
plt.show()

# %% [markdown]
# Pada tabel dapat dilihat untuk komposisi bauran total semua energi, pada Fossil fuel energi ada sebanyak 58.1% sedangkan untuk Renewable Energy sebanyak 41,9%.

# %%
electricity_energy = df[
    ['electricity_from_renewables_percent', 'electricity_from_fossil_percent']
].mean()

plt.figure(figsize=(7, 7))
plt.pie(
    electricity_energy,
    labels=['Electricity from Renewables', 'Electricity from Fossil'],
    autopct='%1.1f%%',
    startangle=140
)
plt.title('Komposisi Bauran Energi (Produksi Listrik)')
plt.axis('equal')
plt.show()

# %% [markdown]
# Pada tabel dapat dilihat untuk komposisi bauran Produksi Listrik, pada listrik yang berasal dari fossil energy ada sebanyak 68.3% sedangkan listrik yang berasal dari Renewables Energy sebanyak 31.7%.

# %% [markdown]
# ## **Distribution/Distribusi**

# %% [markdown]
# Aktivitas:
# Menganalisis sebaran data persentase energi, termasuk nilai minimum, maksimum, dan outlier.
#
# Tujuan:
# Mengetahui pola distribusi data serta mendeteksi nilai yang tidak wajar.
#
# Visualisasi:
# Histogram

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['renewable_energy_percent'], bins=20, kde=True)
plt.title('Distribusi energi terbarukan')
plt.xlabel('renewable_energy_percent')
plt.ylabel('Frekuensi')
plt.show()

# %% [markdown]
# Histogram tersebut menunjukkan bahwa distribusi persentase energi terbarukan bersifat condong ke kanan (right-skewed), di mana sebagian besar data berada pada rentang nilai rendah, khususnya di bawah 20%.

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['electricity_from_renewables_percent'], bins=20, kde=True)
plt.title('Distribusi listrik energi terbarukan')
plt.xlabel('electricity_from_renewables_percent')
plt.ylabel('Frekuensi')
plt.show()

# %% [markdown]
# Histogram distribusi listrik dari energi terbarukan menunjukkan bahwa sebagian besar data berada pada persentase rendah (di bawah 20%), yang menandakan bahwa mayoritas negara masih menghasilkan listrik dari energi terbarukan dalam jumlah yang terbatas. Distribusi data condong ke kanan (right-skewed).

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['electricity_from_fossil_percent'], bins=20, kde=True)
plt.title('Distribusi listrik energi fossil')
plt.xlabel('electricity_from_fossil_percent')
plt.ylabel('Frekuensi')
plt.show()

# %% [markdown]
# Histogram distribusi listrik dari energi fosil menunjukkan bahwa sebagian besar data berada pada persentase tinggi (di atas 50%), bahkan banyak yang mendekati 100%, yang menandakan bahwa pembangkitan listrik di sebagian besar negara masih sangat bergantung pada energi fosil. Distribusi data cenderung condong ke kiri (left-skewed)

# %% [markdown]
# ## **Relationship/Hubungan**

# %% [markdown]
# Aktivitas:
# Menganalisis hubungan antara energi terbarukan dan energi fosil serta hubungannya dengan waktu (tahun).
#
# Tujuan:
# Mengetahui pola hubungan antar variabel dan melihat tren perubahan energi.
#
# Visualisasi:
# Heatmap

# %%
corr_data = df[[
    'year',
    'renewable_energy_percent',
    'fossil_fuel_energy_percent',
    'electricity_from_renewables_percent',
    'electricity_from_fossil_percent'
]].dropna()

corr_matrix = corr_data.corr()

plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Heatmap Korelasi Energi Terbarukan, Energi Fosil, dan Tahun')
plt.show()

# %% [markdown]
# Heatmap menunjukkan bahwa energi terbarukan dan energi fosil memiliki hubungan saling menggantikan. Peningkatan energi terbarukan cenderung diikuti penurunan energi fosil (korelasi negatif). Listrik dari energi terbarukan berkorelasi positif dengan total energi terbarukan dan sangat negatif dengan listrik dari energi fosil, menandakan pergeseran sumber listrik. Sementara itu, hubungan variabel energi dengan tahun relatif lemah, sehingga tren perubahan tidak selalu konsisten setiap tahun.

# %% [markdown]
# # **Data Preparation**

# %%
file = "/content/drive/MyDrive/Check_point_AVD/global_renewable_and_fossil_fuel_energy_2000_2022.csv"
df = pd.read_csv(file)

df
# Out:
#        country country_code                      region  year  \
# 0        Aruba          ABW  Latin America & Caribbean   2000
# 1        Aruba          ABW  Latin America & Caribbean   2001
# 2        Aruba          ABW  Latin America & Caribbean   2002
# 3        Aruba          ABW  Latin America & Caribbean   2003
# 4        Aruba          ABW  Latin America & Caribbean   2004
# ...        ...          ...                         ...   ...
# 4852  Zimbabwe          ZWE         Sub-Saharan Africa   2018
# 4853  Zimbabwe          ZWE         Sub-Saharan Africa   2019
# 4854  Zimbabwe          ZWE         Sub-Saharan Africa   2020
# 4855  Zimbabwe          ZWE         Sub-Saharan Africa   2021
# 4856  Zimbabwe          ZWE         Sub-Saharan Africa   2022
#
#       renewable_energy_percent  fossil_fuel_energy_percent  \
# 0                          0.2                         NaN
# 1                          0.2                         NaN
# ...

# %% [markdown]
# ## **Tipe Data**

# %%
df.dtypes
# Out:
# country                                 object
# country_code                            object
# region                                  object
# year                                     int64
# renewable_energy_percent               float64
# fossil_fuel_energy_percent             float64
# electricity_from_renewables_percent    float64
# electricity_from_fossil_percent        float64
# total_electricity_share                float64
# clean_energy_dominant                     bool
# dtype: object

# %% [markdown]
# Untuk tipe data tidak ada yang perlu diubah karena sudah sesuai.

# %% [markdown]
# ## **Inconsistent Values**

# %% [markdown]
# Pada Inconsistent Values tidak terdapat data dengan Inconsistent Values

# %% [markdown]
# ## **Missing Values**

# %%
pd.DataFrame(df.isna().sum() / len(df) * 100, columns=['Null Ratio in %'])
# Out:
#                                      Null Ratio in %
# country                                     0.000000
# country_code                                0.000000
# region                                      0.000000
# year                                        0.000000
# renewable_energy_percent                    3.191270
# fossil_fuel_energy_percent                 30.409718
# electricity_from_renewables_percent         9.491456
# electricity_from_fossil_percent             4.303068
# total_electricity_share                    10.253243
# clean_energy_dominant                       0.000000

# %%
df['renewable_energy_percent'] = df['renewable_energy_percent'].fillna(df['renewable_energy_percent'].dropna().median())

# %%
df['fossil_fuel_energy_percent'] = df['fossil_fuel_energy_percent'].fillna(df['fossil_fuel_energy_percent'].dropna().median())

# %%
df['electricity_from_renewables_percent'] = df['electricity_from_renewables_percent'].fillna(df['electricity_from_renewables_percent'].dropna().median())

# %%
df['electricity_from_fossil_percent'] = df['electricity_from_fossil_percent'].fillna(df['electricity_from_fossil_percent'].dropna().median())

# %%
df['total_electricity_share'] = df['total_electricity_share'].fillna(df['total_electricity_share'].dropna().median())

# %% [markdown]
# Disini saya mengimputasi semua kolom yang memiliki missing values yaitu renewable_energy_percent, fossil_fuel_energy_percent, electricity_from_renewables_percent,
# electricity_from_fossil_percent, dan total_electricity_share menggunakan median

# %% [markdown]
# ## **Duplicated Values**

# %%
df.duplicated(subset=["country", "year"]).sum()
# Out:
# np.int64(0)

# %% [markdown]
# Pada dataset ini Duplicated Values dicek dengan menggunakan kolom country dan year. Hasilnya menunjukkan pada dataset tersebut tidak terdapat duplicated values satupun.

# %% [markdown]
# ## **Outliers**

# %%
columns_to_impute = ["total_electricity_share", "total_electricity_share"]

for col in columns_to_impute:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    df.loc[:, col] = df[col].clip(lower=lower_bound, upper=upper_bound)

# %%
display(results_df)
# Out:
# Kolom                                Persentase Outliers
# year                                            0.000000
# renewable_energy_percent                        0.000000
# fossil_fuel_energy_percent                      0.000000
# electricity_from_renewables_percent             0.000000
# electricity_from_fossil_percent                 0.000000
# total_electricity_share                        25.427218

# %% [markdown]
# Pada dataset ini terdapat 25% total_electricity_share yang outlier.

# %% [markdown]
# ## **Construct Data**

# %%
df = df.sort_values(["country", "year"])
df["renewable_growth"] = df.groupby("country")["renewable_energy_percent"].diff()
df["renewable_growth"] = df["renewable_growth"].fillna(0)

# %%
def tren_perkembangan_renewable_energy(growth):
    if growth > 0:
        return 'Meningkat'
    elif growth < 0:
        return 'Menurun'
    else:
        return 'Stabil'

df['tren_perkembangan_renewable_energy'] = df['renewable_growth'].apply(tren_perkembangan_renewable_energy)

# %% [markdown]
# Disini Saya menambahkan 2 kolom baru yaitu renewable_growth	dan tren_perkembangan_renewable_energy untuk dapat mrlihat tren arah perkembangan energi terbarukan ini apakah meningkat, stabil atau menurun.

# %% [markdown]
# ## **Data reduction**

# %%
df = df[(df.select_dtypes(include=['float64','int64']) >= 0).all(axis=1)]

# %%
df = df.drop('country_code', axis=1)

# %% [markdown]
# Disini saya menghapus kolom country_code karena untuk country code pada dataset tigak terlalu berguna pada analisis perkembangan tren dan juga sudah ada country dan itu cukup.

# %%
df.head()
# Out:
#         country                                             region  year  \
# 23  Afghanistan  Middle East, North Africa, Afghanistan & Pakistan  2000
# 24  Afghanistan  Middle East, North Africa, Afghanistan & Pakistan  2001
# 27  Afghanistan  Middle East, North Africa, Afghanistan & Pakistan  2004
# 35  Afghanistan  Middle East, North Africa, Afghanistan & Pakistan  2012
# 36  Afghanistan  Middle East, North Africa, Afghanistan & Pakistan  2013
#
#     renewable_energy_percent  fossil_fuel_energy_percent  \
# 23                      45.0                   39.038562
# 24                      45.6                   39.038562
# 27                      44.2                   39.038562
# 35                      15.4                   39.038562
# 36                      16.9                   39.038562
#
#     electricity_from_renewables_percent  electricity_from_fossil_percent  \
# 23                            93.537318                         6.462682
# ...

# %% [markdown]
# # **Visualisasi data**

# %% [markdown]
# ## **Memuat Dataset**

# %%
file = '/content/UTS_Nazmi Ramadanii_031.xlsx'

df = pd.read_excel(file)
df
# Out:
#           country                                             region  year  \
# 0     Afghanistan  Middle East, North Africa, Afghanistan & Pakistan  2000
# 1     Afghanistan  Middle East, North Africa, Afghanistan & Pakistan  2001
# 2     Afghanistan  Middle East, North Africa, Afghanistan & Pakistan  2004
# 3     Afghanistan  Middle East, North Africa, Afghanistan & Pakistan  2012
# 4     Afghanistan  Middle East, North Africa, Afghanistan & Pakistan  2013
# ...           ...                                                ...   ...
# 2845     Zimbabwe                                Sub-Saharan Africa   2015
# 2846     Zimbabwe                                Sub-Saharan Africa   2016
# 2847     Zimbabwe                                Sub-Saharan Africa   2017
# 2848     Zimbabwe                                Sub-Saharan Africa   2019
# 2849     Zimbabwe                                Sub-Saharan Africa   2020
#
#       renewable_energy_percent  fossil_fuel_energy_percent  \
# ...

# %% [markdown]
# ## **Bar Chart**

# %%
perbandinganregion = df.groupby("region")[["renewable_energy_percent","fossil_fuel_energy_percent"]].mean()

perbandinganregion_reset = perbandinganregion.reset_index()

df_melted = perbandinganregion_reset.melt(id_vars='region', var_name='energy_type', value_name='percentage')

plt.figure(figsize=(14, 7))
sns.barplot(x='region', y='percentage', hue='energy_type', data=df_melted, palette='viridis')
plt.title('Perbandingan Rata-rata Persentase Energi Terbarukan dan Fosil antar Wilayah')
plt.xlabel('Wilayah')
plt.ylabel('Rata-rata Persentase')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Tipe Energi')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Insight**
#
# Bar Chart menujjukkan perbandingan energi terbarukan dan fossil di seluruh wilayah, dapat dilihat kebanyakan region rata rata persentase penggunaan energy fosil lebih banyak dibandingkan energy terbarukan. hanya pada region South Asia dan Sub-Saharan Africa yang persentase penggunaan energy terbarukannya lebih banyak. Region yang memiliki nilai energi fosil lebih tinggi menunjukkan bahwa infrastruktur energi bersih masih terbatas atau kebijakan energi terbarukan belum berjalan maksimal.
#
#
# ---
# **Action**
#
# Pemerintah di region yang masih bergantung pada energi fosil dapat meningkatkan investasi pada energi terbarukan seperti tenaga surya, angin, dan hidro. Selain itu, kerja sama internasional dan transfer teknologi energi bersih dapat membantu mempercepat transisi energi di wilayah yang masih tertinggal.

# %% [markdown]
# ## **Pie Chart**

# %%
tren_counts = df['tren_perkembangan_renewable_energy'].value_counts()

plt.figure(figsize=(10, 8))
plt.pie(tren_counts, labels=tren_counts.index, autopct='%1.1f%%', startangle=140, colors=plt.cm.Paired.colors)
plt.title('Tren Perkembangan Energi Terbarukan')
plt.ylabel('')
plt.axis('equal')
plt.show()

# %% [markdown]
# **Insight**
#
# Pie Chart menunjjukkan tren perkembangan energi terbarukan dari tahun 2000 hingga 2022 terlihat bahwa 68.5% negara mengalami peningkatan dalam penggunaan energy terbarukan. Ini menunjukkan adanya kesadaran global yang semakin tinggi terhadap pentingnya penggunaan energi bersih untuk mengurangi ketergantungan pada bahan bakar fosil dan menekan emisi karbon. namun masih ada 31,5% negara yang stabil.
#
# ---
# **Action**
#
# Negara yang masih stabil dalam tren perkembangan energi terbarukan sebaiknya melakukan investasi pada teknologi energi terbarukan seperti tenaga surya, angin, dan hidro serta memberikan aturan bagi sektor industri untuk beralih ke sumber energi yang lebih ramah lingkungan. Kerja sama internasional dan transfer teknologi juga bisa menjadi strategi untuk membantu negara yang masih tertinggal dalam pengembangan energi terbarukan.

# %% [markdown]
# ## **Line Chart**

# %%
tren_energi_terbarukan = df.groupby("year")["renewable_energy_percent"].mean()

plt.figure(figsize=(10,6))

plt.plot(tren_energi_terbarukan.index, tren_energi_terbarukan.values, marker='o')

plt.title("Trend of Renewable Energy (2000-2022)")
plt.xlabel("Year")
plt.ylabel("Renewable Energy %")

plt.show()

# %% [markdown]
# **Insight**
#
# Line chart menunjukkan bagaimana perkembangan penggunaan energi terbarukan dari tahun 2000 hingga 2022. grafik menunjukkan pada awal tahun 200 tren energi terbarukan sangat tinggi sekitar 31% namun untuk tahun tahun selanjutnya mengalami penurunan dan kenaikan. Pada tren mengalami penurunan yang cukup signifikan namun kembali naik untuk tahun berikutnya, pada tahun 2015 dan selanjutnya tren mengalami kenaikan dan kembali turun di sekitar tahun 2019 menjadi 20% dan kembali naik cukup besar menjadi 28% pada tahun 2020 dan kembali turun di 2022.
#
# ---
# **Action**
#
# Untuk menjaga tren pertumbuhan tetap stabil pemerintah tiap negara perlu meningkatkan investasi dalam teknologi energi bersih serta mengembangkan kebijakan energi yang berkelanjutan. Bisa juga dengan peningkatan kualitas SDM agar kesadaran terhadap penggunaan energi ramah lingkungan dan juga dapat membantu mempercepat transisi energi.

# %% [markdown]
# ## **Histogram**

# %%
plt.figure(figsize=(8, 5))
sns.histplot(df['renewable_energy_percent'], bins=20, kde=True, color='green')
plt.title('Distribusi Persentase Energi Terbarukan')
plt.xlabel('Persentase Energi Terbarukan')
plt.ylabel('Frekuensi')
plt.show()

# %% [markdown]
# **Insight**
#
# Histogram menunjukkan hasil distribusi persentase energi terbarukan. sebagian besar negara memiliki tingkat penggunaan energi terbarukan pada kisaran menengah, sedangkan hanya sebagian kecil negara yang memiliki tingkat penggunaan energi terbarukan sangat tinggi atau sangat rendah. Hal ini menunjukkan bahwa sebagian besar negara masih berada pada tahap transisi menuju penggunaan energi terbarukan secara lebih luas.
#
# ---
# **Action**
#
# Pemerintah harus mendorong peningkatan penggunaan energi terbarukan melalui pengembangan teknologi energi yang lebih efisien serta memberikan dukungan kebijakan kepada sektor industri untuk menggunakan energi yang lebih ramah lingkungan.

# %% [markdown]
# ## **Boxplot**

# %%
avg_renewable = df.groupby('region')['renewable_energy_percent'].mean().nlargest(5).index

Region_avg_renewable = df.groupby('region')['renewable_energy_percent'].mean().nlargest(7).index

df_top5_countries = df[df['region'].isin(Region_avg_renewable)]

plt.figure(figsize=(12, 7))
sns.boxplot(x='region', y='renewable_energy_percent', data=df_top5_countries, palette='turbo', medianprops=dict(color='red'), hue='region', legend=False)
plt.title('Distribusi Persentase Energi Terbarukan Region', fontsize=16)
plt.xlabel('Region', fontsize=12)
plt.ylabel('Persentase Energi Terbarukan', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Insight**
#
# Pada boxplot menunjukkan sebagian besar data berada pada rentang nilai tertentu yang ditunjukkan oleh kotak utama, dengan garis di dalam kotak yang menunjukkan nilai tengah.sebagian besar negara memiliki persentase penggunaan energi terbarukan yang relatif berada di kisaran yang sama. Namun terdapat beberapa titik yang berada di luar batas atas yang disebut outliers seperti pada region Latin America & Caribbean, Europe & central Asia, East & Pacific, dan Middle East, North Africa, Afghanistan, & Pakistan. Titik ini menunjukkan persentase energi terbarukan yang jauh lebih tinggi dibandingkan negara lainnya.
#
#
# ---
# **Action**
#
# Langkah yang dapat dilakukan adalah melakukan analisis lebih lanjut terhadap negara atau wilayah yang termasuk dalam outliers. Negara dengan persentase energi terbarukan yang sangat tinggi dapat dipelajari sebagai contoh keberhasilan dalam pengembangan energi ramah lingkungan.

# %% [markdown]
# ## **Scatter Plot**

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df['renewable_energy_percent'], df['fossil_fuel_energy_percent'], alpha=0.7, color='teal')
plt.title('Hubungan antara Energi Terbarukan dan Fosil', fontsize=16)
plt.xlabel('Renewable Energy %', fontsize=12)
plt.ylabel('Fossil Fuel Energy %', fontsize=12)
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Insight**
#
# Setiap titik pada scatter plot mewakili data dari suatu negara. Dari pola titik yang terlihat, terdapat kecenderungan bahwa ketika nilai renewable_energy_percent meningkat, nilai fossil_fuel_energy_percent cenderung menurun. Hal ini menunjukkan bahwa beberapa negara mulai beralih dari penggunaan energi fosil seperti batu bara, minyak, dan gas menuju energi yang lebih ramah lingkungan seperti tenaga surya, angin, atau air. Namun, titik-titik pada grafik tidak membentuk garis yang sangat jelas dan masih cukup tersebar, yang berarti tidak semua negara memiliki pola yang sama dalam penggunaan energi tersebut.
#
# ---
# **Action**
#
# Negara yang masih memiliki persentase energi fosil yang tinggi dapat mulai didorong untuk meningkatkan penggunaan energi terbarukan melalui pengembangan teknologi energi bersih dan kebijakan pengurangan penggunaan bahan bakar fosil.

# %% [markdown]
# ## **Bubble Chart**

# %%
plt.figure(figsize=(12, 8))
sns.scatterplot(x='renewable_energy_percent', y='fossil_fuel_energy_percent', size='total_electricity_share', hue='region', data=df, sizes=(50, 1000), alpha=0.7, palette='viridis')
plt.title('Hubungan Energi Terbarukan, Fosil, dan Total Penggunaan Listrik per Wilayah', fontsize=16)
plt.xlabel('Renewable Energy %', fontsize=12)
plt.ylabel('Fossil Fuel Energy %', fontsize=12)
plt.grid(True)
plt.legend(title='Wilayah', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Insight**
#
# Dapat dilihat bahwa Region dengan produksi listrik yang besar masih memiliki variasi dalam penggunaan energi terbarukan dan energi fosil. Hal ini menunjukkan bahwa beberapa Region besar masih bergantung pada energi fosil dalam sistem kelistrikan mereka.
#
# ---
# **Action**
#
# untuk region yang memiliki penggunaan listrik besar tetapi masih sangat bergantung pada energi fosil. Region tersebut bisa dijadikan fokus utama dalam pengembangan energi terbarukan agar lebih ramah lingkungan.

# %% [markdown]
# ## **Heatmap**

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(data=df[['renewable_energy_percent', 'fossil_fuel_energy_percent','electricity_from_renewables_percent','electricity_from_fossil_percent','renewable_growth']].corr(),
            annot=True,
            cmap='viridis',
            fmt='.2f')
plt.title('Korelasi Variabel Energy')
plt.show()

# %% [markdown]
# **Insight**
#
# Pada heatmap dapat dilihat variabel yang berkaitan dengan energi terbarukan memiliki nilai korelasi positif yang cukup tinggi, yang berarti ketika persentase energi terbarukan meningkat maka produksi listrik dari energi terbarukan juga cenderung meningkat. Selain itu terdapat korelasi negatif antara renewable_energy_percent dan fossil_fuel_energy_percent, yang menunjukkan bahwa peningkatan penggunaan energi terbarukan biasanya diikuti dengan penurunan penggunaan energi fosil.
#
# ---
# **Action**
#
# langkah yang dapat dilakukan ke depannya adalah mendorong peningkatan penggunaan energi terbarukan melalui pengembangan teknologi energi bersih seperti tenaga surya, angin, dan air. Selain itu, analisis ini juga dapat digunakan untuk membantu pemerintah atau peneliti dalam merancang kebijakan energi yang lebih berkelanjutan, sehingga penggunaan energi fosil dapat dikurangi secara bertahap dan digantikan dengan sumber energi yang lebih ramah lingkungan.

# %% [markdown]
# # **Menyimpan Dataset**

# %%
df.to_excel('UTS_Nazmi Ramadanii_031.xlsx', index=False)
